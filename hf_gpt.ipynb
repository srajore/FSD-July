# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_huggingface.llms import HuggingFacePipeline

hf = HuggingFacePipeline.from_model_id(
    model_id="gpt2",
    task="text-generation",
    pipeline_kwargs={"max_new_tokens": 10},
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 from langchain_huggingface.llms import HuggingFacePipeline
#       2
# ----> 3 hf = HuggingFacePipeline.from_model_id(
#       4     model_id="gpt2",
#       5     task="text-generation",
#       6     pipeline_kwargs={"max_new_tokens": 10},
#
# File c:\Users\SR43993\Downloads\FSD-July\.venv\Lib\site-packages\langchain_huggingface\llms\huggingface_pipeline.py:218, in HuggingFacePipeline.from_model_id(cls, model_id, task, backend, device, device_map, model_kwargs, pipeline_kwargs, batch_size, **kwargs)
#     211 else:
#     212     model_cls = (
#     213         AutoModelForCausalLM
#     214         if task == "text-generation"
#     215         else AutoModelForSeq2SeqLM
#     216     )
# --> 218 model = model_cls.from_pretrained(model_id, **_model_kwargs)
#     220 if tokenizer.pad_token is None:
#     221     if model.config.pad_token_id is not None:
#
# File c:\Users\SR43993\Downloads\FSD-July\.venv\Lib\site-packages\transformers\models\auto\auto_factory.py:402, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     400         if parent_quant is not None:
#     401             config.quantization_config = parent_quant
# --> 402     return model_class.from_pretrained(
#     403         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     404     )
#     405 raise ValueError(
#     406     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     407     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping)}."
#     408 )
#
# File c:\Users\SR43993\Downloads\FSD-July\.venv\Lib\site-packages\transformers\modeling_utils.py:4267, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, fusion_config, disable_mmap, *model_args, **kwargs)
#    4262     logger.warning_once(
#    4263         "A kernel_config was provided but use_kernels is False; setting use_kernels=True automatically. To suppress this warning, explicitly set use_kernels to True."
#    4264     )
#    4265     use_kernels = True
# -> 4267 checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    4268     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4269     variant=variant,
#    4270     gguf_file=gguf_file,
#    4271     use_safetensors=use_safetensors,
#    4272     download_kwargs=download_kwargs_with_commit,
#    4273     user_agent=user_agent,
#    4274     is_remote_code=cls.is_remote_code(),
#    4275     transformers_explicit_filename=getattr(config, "transformers_weights", None),
#    4276     tqdm_class=tqdm_class,
#    4277 )
#    4279 is_quantized = hf_quantizer is not None
#    4281 # Find the correct dtype based on current state
#
# File c:\Users\SR43993\Downloads\FSD-July\.venv\Lib\site-packages\transformers\modeling_utils.py:682, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, variant, gguf_file, use_safetensors, user_agent, is_remote_code, transformers_explicit_filename, download_kwargs, tqdm_class)
#     670 can_auto_convert = (
#     671     not is_offline_mode()  # for obvious reasons
#     672     # If we are in a CI environment or in a pytest run, we prevent the conversion
#    (...)    675     and subfolder == ""  # converter bot does not work on subfolders
#     676 )
#     678 try:
#     679     # Load from URL or cache if already cached
#     680     # Since we set _raise_exceptions_for_missing_entries=False, we don't get an exception but a None
#     681     # result when internet is up, the repo and revision exist, but the file does not.
# --> 682     resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#     684     # Try safetensors files first if not already found
#     685     if resolved_archive_file is None and filename == _add_variant(SAFE_WEIGHTS_NAME, variant):
#     686         # Maybe the checkpoint is sharded, we try to grab the index name in this case.
#
# File c:\Users\SR43993\Downloads\FSD-July\.venv\Lib\site-packages\transformers\utils\hub.py:293, in cached_file(path_or_repo_id, filename, **kwargs)
#     238 def cached_file(
#     239     path_or_repo_id: str | os.PathLike,
#     240     filename: str,
#     241     **kwargs,
#     242 ) -> str | None:
#     243     """
#     244     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     245
#    (...)    291     ```
#     292     """
# --> 293     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     294     file = file[0] if file is not None else file
#     295     return file
#
# File c:\Users\SR43993\Downloads\FSD-July\.venv\Lib\site-packages\transformers\utils\hub.py:437, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     434 try:
#     435     if len(full_filenames) == 1:
#     436         # This is slightly better for only 1 file
# --> 437         hf_hub_download(
#     438             path_or_repo_id,
#     439             filenames[0],
#     440             subfolder=None if len(subfolder) == 0 else subfolder,
#     441             repo_type=repo_type,
#     442             revision=revision,
#     443             cache_dir=cache_dir,
#     444             user_agent=user_agent,
#     445             force_download=force_download,
#     446             proxies=proxies,
#     447             token=token,
#     448             local_files_only=local_files_only,
#     449             tqdm_class=tqdm_class,
#     450         )
#     451     else:
#     452         snapshot_download(
#     453             path_or_repo_id,
#     454             allow_patterns=full_filenames,
#    (...)    463             tqdm_class=tqdm_class,
#     464         )
#
# File c:\Users\SR43993\Downloads\FSD-July\.venv\Lib\site-packages\huggingface_hub\utils\_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File c:\Users\SR43993\Downloads\FSD-July\.venv\Lib\site-packages\huggingface_hub\file_download.py:1013, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#     992     return _hf_hub_download_to_local_dir(
#     993         # Destination
#     994         local_dir=local_dir,
#    (...)   1010         dry_run=dry_run,
#    1011     )
#    1012 else:
# -> 1013     return _hf_hub_download_to_cache_dir(
#    1014         # Destination
#    1015         cache_dir=cache_dir,
#    1016         # File info
#    1017         repo_id=repo_id,
#    1018         filename=filename,
#    1019         repo_type=repo_type,
#    1020         revision=revision,
#    1021         # HTTP info
#    1022         endpoint=endpoint,
#    1023         etag_timeout=etag_timeout,
#    1024         headers=hf_headers,
#    1025         token=token,
#    1026         # Additional options
#    1027         local_files_only=local_files_only,
#    1028         force_download=force_download,
#    1029         tqdm_class=tqdm_class,
#    1030         dry_run=dry_run,
#    1031     )
#
# File c:\Users\SR43993\Downloads\FSD-July\.venv\Lib\site-packages\huggingface_hub\file_download.py:1236, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1233 # Local file doesn't exist or etag isn't a match => retrieve file from remote (or cache)
#    1235 with WeakFileLock(lock_path):
# -> 1236     _download_to_tmp_and_move(
#    1237         incomplete_path=Path(blob_path + ".incomplete"),
#    1238         destination_path=Path(blob_path),
#    1239         url_to_download=url_to_download,
#    1240         headers=headers,
#    1241         expected_size=expected_size,
#    1242         filename=filename,
#    1243         force_download=force_download,
#    1244         etag=etag,
#    1245         xet_file_data=xet_file_data,
#    1246         tqdm_class=tqdm_class,
#    1247     )
#    1248     if not os.path.exists(pointer_path):
#    1249         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File c:\Users\SR43993\Downloads\FSD-July\.venv\Lib\site-packages\huggingface_hub\file_download.py:1920, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, headers, expected_size, filename, force_download, etag, xet_file_data, tqdm_class)
#    1918 if xet_file_data is not None and is_xet_available():
#    1919     logger.debug("Xet Storage is enabled for this repo. Downloading file from Xet Storage..")
# -> 1920     xet_get(
#    1921         incomplete_path=tmp_path,
#    1922         xet_file_data=xet_file_data,
#    1923         headers=headers,
#    1924         expected_size=expected_size,
#    1925         displayed_filename=filename,
#    1926         tqdm_class=tqdm_class,
#    1927     )
#    1928 else:
#    1929     if xet_file_data is not None and not constants.HF_HUB_DISABLE_XET:
#
# File c:\Users\SR43993\Downloads\FSD-July\.venv\Lib\site-packages\huggingface_hub\file_download.py:563, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, tqdm_class, _tqdm_bar)
#     553 with XetDownloadProgressReporter(
#     554     reconstruction_desc=f"{displayed_filename}: reconstructing file",
#     555     transfer_desc=f"{displayed_filename}: downloading bytes",
#    (...)    560     external_reconstruction_bar=_tqdm_bar,
#     561 ) as progress:
#     562     try:
# --> 563         with session.new_file_download_group(
#     564             token_refresh_url=xet_file_data.refresh_route,
#     565             token_refresh_headers=headers,
#     566             custom_headers=xet_headers,
#     567             progress_callback=progress.update_progress,
#     568         ) as group:
#     569             group.start_download_file(
#     570                 XetFileInfo(xet_file_data.file_hash, expected_size), str(incomplete_path.absolute())
#     571             )
#     572     except KeyboardInterrupt:
#
# KeyboardInterrupt:
