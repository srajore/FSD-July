# %%
import os
from openai import AzureOpenAI

endpoint = "https://fsd-july.openai.azure.com/"
model_name = "gpt-5.2"
deployment = "gpt-5.2"

subscription_key = ""
api_version = "2024-12-01-preview"

client = AzureOpenAI(
    api_version=api_version,
    azure_endpoint=endpoint,
    api_key=subscription_key,
)

response = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": "I am going to Pune, what should I see?",
        }
    ],
    max_completion_tokens=16384,
    model=deployment
)

print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[1], line 11
#       7
#       8 subscription_key = ""
#       9 api_version = "2024-12-01-preview"
#      10
# ---> 11 client = AzureOpenAI(
#      12     api_version=api_version,
#      13     azure_endpoint=endpoint,
#      14     api_key=subscription_key,
#
# File c:\Users\SR43993\Downloads\FSD-July\.venv\Lib\site-packages\openai\lib\azure.py:258, in AzureOpenAI.__init__(self, api_version, azure_endpoint, azure_deployment, api_key, admin_api_key, workload_identity, azure_ad_token, azure_ad_token_provider, organization, project, webhook_secret, websocket_base_url, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     254 if api_key is None:
#     255     # define a sentinel value to avoid any typing issues
#     256     api_key = API_KEY_SENTINEL
# --> 258 super().__init__(
#     259     api_key=api_key,
#     260     admin_api_key=admin_api_key,
#     261     organization=organization,
#     262     project=project,
#     263     webhook_secret=webhook_secret,
#     264     base_url=base_url,
#     265     timeout=timeout,
#     266     max_retries=max_retries,
#     267     default_headers=default_headers,
#     268     default_query=default_query,
#     269     http_client=http_client,
#     270     websocket_base_url=websocket_base_url,
#     271     _strict_response_validation=_strict_response_validation,
#     272     _enforce_credentials=_enforce_credentials,
#     273 )
#     274 self._api_version = api_version
#     275 self._azure_ad_token = azure_ad_token
#
# File c:\Users\SR43993\Downloads\FSD-July\.venv\Lib\site-packages\openai\_client.py:230, in OpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, provider, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     220 self.admin_api_key = admin_api_key if provider_runtime is None else None
#     222 if (
#     223     provider_runtime is None
#     224     and _enforce_credentials
#    (...)    228     and self.admin_api_key is None
#     229 ):
# --> 230     raise OpenAIError(
#     231         "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#     232     )
#     234 if organization is None and provider_runtime is None:
#     235     organization = os.environ.get("OPENAI_ORG_ID")
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.
