# %%
import os
from openai import AzureOpenAI

endpoint = "https://fsd-july.openai.azure.com/"
model_name = "gpt-5.2"
deployment = "gpt-5.2"

subscription_key = ""
api_version = "2024-12-01-preview"

client = AzureOpenAI(
    api_version=api_version,
    azure_endpoint=endpoint,
    api_key=subscription_key,
)

response = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": "I am going to Pune, what should I see?",
        }
    ],
    max_completion_tokens=16384,
    model=deployment
)

print(response.choices[0].message.content)
# Out:
# In and around Pune, here are some of the best things to see—mixing history, viewpoints, food, and easy day trips:
#
# ## In the city (top picks)
# - **Shaniwar Wada**: Iconic Maratha-era fortification in the heart of the city (go in the evening for the light-and-sound vibe if it’s running).
# - **Aga Khan Palace**: Beautiful grounds and an important place in India’s freedom movement.
# - **Sinhagad Fort** (early morning/late afternoon): Great views and a classic Pune experience—try **kanda bhaji** and **curd** at the top.
# - **Pataleshwar Cave Temple**: Rock-cut cave temple right in the city; quick but memorable.
# - **Saras Baug + Parvati Hill**: Nice for a relaxed stroll and a viewpoint over the city.
#
# ## Culture, museums, and markets
# - **Raja Dinkar Kelkar Museum**: One of the best museums in India for everyday art and antiques (very Pune).
# - **Mandai (Mahatma Phule Market)** + nearby old-city lanes: Great for local color, spices, and street snacks.
# - **FC Road / JM Road**: Shopping, cafés, and street food; lively evenings.
#
# ## Nature / chill spots
# - **Pashan Lake** or **Vetal Tekdi (Arai Hills)**: Easy nature walks inside the city, especially pleasant early morning.
# - **Osho Garden (Koregaon Park area)**: Calm green space; Koregaon Park also has many good cafés.
#
# ## Easy day trips (highly recommended)
# - **Lonavala–Khandala** (monsoon is stunning): Viewpoints, short hikes, and waterfalls in season.
# - **Lavasa** (if you like scenic drives; opinions vary on the town itself).
# - **Mulshi Lake**: Very scenic, great for a relaxed half-day drive.
# - **Bhigwan Bird Sanctuary** (seasonal): Excellent for birdwatching (best in winter).
#
# ## If you like forts (Pune is perfect for this)
# - **Rajgad Fort**: More adventurous than Sinhagad; fantastic views.
# - **Torna Fort**: A bigger trek; great if you want something less touristy.
#
# ## Food to try in Pune
# - **Misal pav** (Katakirr is famous; many locals have their own favorite spot)
# - **Vada pav**, **sabudana khichdi**, **thalipeeth**
# - **Mastani** (thick milkshake-style dessert drink; try at Sujata Mastani)
#
# If you tell me **how many days** you have, your **interests** (history/treks/food/nightlife/with family), and **where you’re staying** (e.g., Shivajinagar, Koregaon Park, Hinjawadi), I can suggest a tight itinerary with travel times.
